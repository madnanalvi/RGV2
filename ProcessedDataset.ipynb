# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
import os
sys.path.append(os.path.abspath("/content/drive/MyDrive/PhD/py/"))
from impfunc import infer,func
verbose='0'
path='/content/drive/MyDrive/PhD/csv/'
import pandas as pd
import numpy as np
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import Dataset

# %%
log = pd.read_csv(path+'21-xData.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [392,2012,4240]
benign='benign'
family='xData'
df = func.preProcessData(log,'0')
#df = df[df['fname'].str.contains(r'C:\\Users\\alvi\\Documents')]
df['family'] =  np.where(df['pid'].isin(MaliciousProcessIDs), family, benign)
df['label'] = np.where(df['pid'].isin(MaliciousProcessIDs), '1', '0')
print('1 '+str(df.shape))

log = pd.read_csv(path+'22a-WannaCry_log1.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [4984]
family='WannaCry'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('2 '+str(df.shape))

log = pd.read_csv(path+'22b-WannaCry_log2.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [6760]
family='WannaCry'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('3 '+str(df.shape))

log = pd.read_csv(path+'22c-WannaCry_log3.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [6992]
family='WannaCry'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('4 '+str(df.shape))

log = pd.read_csv(path+'22d-WannaCry_log4.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [6820]
family='WannaCry'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('5 '+str(df.shape))

log = pd.read_csv(path+'22e-WannaCry_log5.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [1324]
family='WannaCry'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('6 '+str(df.shape))

log = pd.read_csv(path+'22f-WannaCry_log6.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [6408]
family='WannaCry'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('7 '+str(df.shape))

log = pd.read_csv(path+'22g-WannaCry_log7.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [3380]
family='WannaCry'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('8 '+str(df.shape))

log = pd.read_csv(path+'22h-WannaCry_log8.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [7408]
family='WannaCry'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('9 '+str(df.shape))

log = pd.read_csv(path+'22i-WannaCry_log9.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [4536]
family='WannaCry'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('10 '+str(df.shape))

log = pd.read_csv(path+'22j-WannaCry_log10.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [5560]
family='WannaCry'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('11 '+str(df.shape))

log = pd.read_csv(path+'22k-WannaCry_log11.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [5008,3828]
family='WannaCry'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('12 '+str(df.shape))

log = pd.read_csv(path+'23-jigsaw.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [2188]
family='Jigsaw'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('13 '+str(df.shape))

log = pd.read_csv(path+'24-cerber.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [4304]
family='Cerber'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('14 '+str(df.shape))

log = pd.read_csv(path+'24b-cerber2.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [1480]
family='Cerber'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('15 '+str(df.shape))

log = pd.read_csv(path+'25-gamma.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [6820,2140]
family='Gamma'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('16 '+str(df.shape))

log = pd.read_csv(path+'11-grandcrab.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [3724]
family='Grandcrab'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('17 '+str(df.shape))

log = pd.read_csv(path+'12-Hive_log1.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [2288]
family='Hive'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('18 '+str(df.shape))

log = pd.read_csv(path+'13-InfinityCrypt.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [5480]
family='InfinityCrypt'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('19 '+str(df.shape))

log = pd.read_csv(path+'14a-Lockbit_log1.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [1016]
family='Lockbit'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('20 '+str(df.shape))

log = pd.read_csv(path+'14b-Lockbit_log2.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [4644]
family='Lockbit'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('21 '+str(df.shape))

log = pd.read_csv(path+'15a-RedBoot_log1.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [440]
family='RedBoot'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family,benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('22 '+str(df.shape))

log = pd.read_csv(path+'15b-RedBoot_log2.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [440]
family='RedBoot'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('23 '+str(df.shape))

log = pd.read_csv(path+'15c-RedBoot_log3.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [440]
family='RedBoot'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('24 '+str(df.shape))

log = pd.read_csv(path+'16-Satana.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [5504]
family='Satana'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('25 '+str(df.shape))

log = pd.read_csv(path+'17-Snatch.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [2832,5024]
family='Snatch'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('26 '+str(df.shape))

log = pd.read_csv(path+'18b-TeslaCrypt.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [796,6104]
family='TeslaCrypt'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('27 '+str(df.shape))

log = pd.read_csv(path+'19-Thanos.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [4632]
family='Thanos'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('28 '+str(df.shape))

log = pd.read_csv(path+'2-Phobos.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [5916]
family='Phobos'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('29 '+str(df.shape))

log = pd.read_csv(path+'3-Quantum_Locker.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [6012]
family='Quantum_Locker'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('30 '+str(df.shape))

log = pd.read_csv(path+'4-7ev3n.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [7960]
family='7ev3n'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('31 '+str(df.shape))

log = pd.read_csv(path+'5-Clop.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [6752]
family='Clop'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('32 '+str(df.shape))

log = pd.read_csv(path+'6a-CoronaVirus1.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [7960,4176]
family='CoronaVirus'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('33 '+str(df.shape))

log = pd.read_csv(path+'6b-CoronaVirus2.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [5024,4316]
family='CoronaVirus'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('34 '+str(df.shape))

log = pd.read_csv(path+'8-Dharma.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [5512,1232]
family='Dharma'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('35 '+str(df.shape))

log = pd.read_csv(path+'9a-GoldenEye1.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [6324,6932]
family='GoldenEye'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('36 '+str(df.shape))

log = pd.read_csv(path+'9b-GoldenEye2.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [6932]
family='GoldenEye'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('37 '+str(df.shape))

log = pd.read_csv(path+'10-Katyusha.csv', on_bad_lines='skip', low_memory=False);
MaliciousProcessIDs = [600,6032]
family='Katyusha'
df1 = func.preProcessData(log,'0')
df1['family'] =  np.where(df1['pid'].isin(MaliciousProcessIDs), family, benign)
df1['label'] = np.where(df1['pid'].isin(MaliciousProcessIDs), '1', '0')
df = pd.concat([df,df1])
print('38 '+str(df.shape))

log = pd.read_csv(path+'1a-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('39 '+str(df.shape))

log = pd.read_csv(path+'1b-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('40 '+str(df.shape))

log = pd.read_csv(path+'1c-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('41 '+str(df.shape))

log = pd.read_csv(path+'1d-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('42 '+str(df.shape))

log = pd.read_csv(path+'1e-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('43 '+str(df.shape))

log = pd.read_csv(path+'1f-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('44 '+str(df.shape))

log = pd.read_csv(path+'1g-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('45 '+str(df.shape))

log = pd.read_csv(path+'1h-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('46 '+str(df.shape))

log = pd.read_csv(path+'1i-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('47 '+str(df.shape))

log = pd.read_csv(path+'1j-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('48 '+str(df.shape))

log = pd.read_csv(path+'1k-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('49 '+str(df.shape))

log = pd.read_csv(path+'1l-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('50 '+str(df.shape))

log = pd.read_csv(path+'1m-benign.csv', on_bad_lines='skip', low_memory=False);
df1 = func.preProcessData(log,'0')
df1['family'] =  benign
df1['label'] = '0'
df = pd.concat([df,df1])
print('51 '+str(df.shape))
# Out:
# 1 (16544, 13)
# 2 (32973, 13)
# 3 (54182, 13)
# 4 (71604, 13)
# 5 (82588, 13)
# 6 (110594, 13)
# 7 (121437, 13)
# 8 (134271, 13)
# 9 (151797, 13)
# 10 (176147, 13)
# 11 (208852, 13)
# 12 (248576, 13)
# 13 (269634, 13)
# 14 (296445, 13)
# 15 (322920, 13)
# 16 (337651, 13)
# 17 (341625, 13)
# 18 (390220, 13)
# 19 (392350, 13)
# 20 (392716, 13)
# 21 (394251, 13)
# 22 (403807, 13)
# 23 (415055, 13)
# 24 (422488, 13)
# 25 (427707, 13)
# 26 (463350, 13)
# 27 (486750, 13)
# 28 (489206, 13)
# 29 (516299, 13)
# 30 (518422, 13)
# 31 (523553, 13)
# 32 (526613, 13)
# 33 (551471, 13)
# 34 (557596, 13)
# 35 (584833, 13)
# 36 (590117, 13)
# 37 (591273, 13)
# 38 (599340, 13)
# 39 (599703, 13)
# 40 (615434, 13)
# 41 (621887, 13)
# 42 (742008, 13)
# 43 (750540, 13)
# 44 (751649, 13)
# 45 (754752, 13)
# 46 (783769, 13)
# 47 (786985, 13)
# 48 (794150, 13)
# 49 (850358, 13)
# 50 (899275, 13)
# 51 (947181, 13)

# %%
df.to_csv('/content/drive/MyDrive/PhD/processedEvents/Processed_events.csv', index=False)

# %% [markdown]
# ###Consolidated

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/drive/MyDrive/PhD/processedEvents/Processed_events.csv')
print('df_Processed'+ str(df.shape))
# Out:
# <ipython-input-2-d23e53ed70ef>:3: DtypeWarning: Columns (0,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/PhD/processedEvents/Processed_events.csv')
# df_Processed(947181, 13)

# %%
#----------------Filter only malicious events from filtered directory to minimize False Positives----------------------------
df_benign = df[(df['label'] ==0)]
print('df benign: '+ str(df_benign.shape))
df_malicious =df[(df['label'] ==1) & ~df['fname'].str.contains('AppData') & ~df['fname'].str.contains(r'C:\\Users\\Default') & ~df['fname'].str.contains(r'C:\\Users\\Public') & ~df['fname'].str.contains(r'C:\\Users\\desktop') ]
print('df malicious: '+ str(df_malicious.shape))
df_Processed = pd.concat([df_benign, df_malicious])
print('Final concatenated: '+ str(df_Processed.shape))
#-----------------------------------------
# Out:
# df benign: (608350, 13)
# df malicious: (230107, 13)
# Final concatenated: (838457, 13)

# %%
df_consolidated = func.consolidate_Events(df_Processed,'0')
#df_consolidated = df_consolidated.fillna(' ')
print('consolidated '+str(df_consolidated.shape))
# Out:
# consolidated (376787, 14)

# %%
df_consolidated['eid_count'] = df_consolidated['eid'].str.len()
df_consolidated['Cleanup'] = df_consolidated['eid'].str.contains('l').astype(int)
df_consolidated['Close'] = df_consolidated['eid'].str.contains('g').astype(int)
df_consolidated['Read'] = df_consolidated['eid'].str.contains('c').astype(int)
df_consolidated['Write'] = df_consolidated['eid'].str.contains('d').astype(int)
df_consolidated['QueryInfo'] = df_consolidated['eid'].str.contains('n').astype(int)
df_consolidated['Create'] = df_consolidated['eid'].str.contains('f').astype(int)
df_consolidated['Delete'] = df_consolidated['eid'].str.contains('b').astype(int)
df_consolidated['Rename'] = df_consolidated['eid'].str.contains('a').astype(int)
df_consolidated['Rename_Read'] = (df_consolidated['eid'].str.contains('a') & df_consolidated['eid'].str.contains('c')).astype(int)
df_consolidated['Rename_Write'] = (df_consolidated['eid'].str.contains('a') & df_consolidated['eid'].str.contains('d')).astype(int)
df_consolidated['Read_Write'] = (df_consolidated['eid'].str.contains('c') & df_consolidated['eid'].str.contains('d')).astype(int)
df_consolidated['Rename_Read_Write'] = (df_consolidated['eid'].str.contains('a') & df_consolidated['eid'].str.contains('c')& df_consolidated['eid'].str.contains('d')).astype(int)
df_consolidated['QueryInfo_Cleanup_Close'] = (df_consolidated['eid'].str.contains('n') & df_consolidated['eid'].str.contains('l')& df_consolidated['eid'].str.contains('g')).astype(int)
df_consolidated['Cleanup_Close'] = (df_consolidated['eid'].str.contains('l') & df_consolidated['eid'].str.contains('g')).astype(int)
df_consolidated['Create_QueryInfo'] = (df_consolidated['eid'].str.contains('f') & df_consolidated['eid'].str.contains('n')).astype(int)

# %%
df_consolidated_encoded=df_consolidated.loc[:, ['eid_count','Rename','Delete','Read','Write','Create','Close','Cleanup','QueryInfo','Rename_Read','Rename_Write','Read_Write','Cleanup_Close','Create_QueryInfo','Rename_Read_Write','QueryInfo_Cleanup_Close','family','label']]

# %%
#Encode FileName and ProcessName using LabelEncoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
#df_consolidated_encoded['pn_enc']=le.fit_transform(df_consolidated['pn'])
#df_consolidated_encoded['fname_enc']= le.fit_transform(df_consolidated['fname'])
df_consolidated_encoded['eid_enc']= le.fit_transform(df_consolidated['eid'])
df_consolidated_encoded['ft_enc']= le.fit_transform(df_consolidated['ft'])
df_consolidated_encoded['family_enc']= le.fit_transform(df_consolidated['family'])

# %%
df_consolidated.to_csv('/content/drive/MyDrive/PhD/processedEvents/Encoded_events.csv', index=False)
df_consolidated_encoded.to_csv('/content/drive/MyDrive/PhD/processedEvents/Consolidated_events.csv', index=False)
print(df_consolidated_encoded['label'].value_counts())
# Out:
# label
# 0    206143
# 1    170644
# Name: count, dtype: int64

# %%
df_consolidated_encoded.sample(10)
# Out:
#         eid_count  Rename  Delete  Read  Write  Create  Close  Cleanup  \
# 210535         17       1       1     1      1       1      1        1
# 179334          3       0       0     1      0       1      0        0
# 321862         11       0       1     1      1       1      1        1
# 130822          4       0       0     1      0       1      0        1
# 320768         11       0       1     1      1       1      1        1
# 16862           4       0       0     1      1       0      1        0
# 353704         11       0       1     1      1       1      1        1
# 303073         17       1       1     1      1       1      1        1
# 22801           3       0       0     1      1       0      0        0
# 214506         17       1       1     1      1       1      1        1
#
#         QueryInfo  Rename_Read  ...  Read_Write  Cleanup_Close  \
# 210535          1            1  ...           1              1
# ...

# %%
df_consolidated.sample(10)
# Out:
#                                                     fname  fn_ftc  pid_ftc  \
# 34409   C:\Users\alvi\Documents\HoneyPot\Data (51)\004...       5     6869
# 339323  C:\Users\alvi\Documents\dd\gg (15)\0015-doc-pa...       4     9485
# 277353     C:\Users\alvi\Documents\434\gggh (10)\gg (100)       5    20597
# 291290  C:\Users\alvi\Documents\434\gggh (95)\0051-zip...       5    20597
# 254295  C:\Users\alvi\Documents\5551\gg (15)\0013-doc-...       5     6829
# 253194        C:\Users\alvi\Documents\dd\gg (52)\0100-pdf       6     6130
# 92585   C:\Users\alvi\Documents\dd\gg (91)\0002-xlsx-p...       4     3673
# 313893  C:\Users\alvi\Documents\dd\gg (14)\0062-doc-no...       4    10836
# 365155  C:\Users\vm1\Downloads\data\Research_\2022\Dee...       6    10096
# 290610  C:\Users\alvi\Documents\434\gggh (93)\0027-zip...       5    20597
#
#                       fts                 ft      FileType                eid  \
# ...
